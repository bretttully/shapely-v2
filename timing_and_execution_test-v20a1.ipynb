# %%
import pandas as pd
import shapely

from shapely_test import shapes
from shapely_test.cases import run_execution_and_timing_test

print(shapely.__version__)
# Out:
# 2.0a1

# %%
generators = [
    getattr(shapes, d)(use_cached_data_if_it_exists=False)
    for d in dir(shapes)
    if d.endswith("Generator") and d != "RandomPolyGenerator"
]

timings = pd.concat(
    [run_execution_and_timing_test(g, n_procs=10, n_tests=50) for g in generators],
    ignore_index=True,
)

timings.groupby(["function", "shapely_version", "data_generator"]).agg({"error": lambda x: len(x.dropna()), "time_ms": "mean"})
# Out:
#                                                                       error  \
# function                       shapely_version data_generator
# gdf1_gdf1_overlay_difference   2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_gdf1_overlay_intersection 2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_gdf1_overlay_union        2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_gdf2_overlay_difference   2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_gdf2_overlay_intersection 2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_gdf2_overlay_union        2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf1_is_valid                  2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf2_gdf1_overlay_difference   2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf2_gdf2_overlay_difference   2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf2_gdf2_overlay_intersection 2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf2_gdf2_overlay_union        2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
# gdf2_is_valid                  2.0a1           random_center_targets      0
#                                                random_radius_targets      0
#                                                spots                      0
#
#                                                                           time_ms
# function                       shapely_version data_generator
# gdf1_gdf1_overlay_difference   2.0a1           random_center_targets   187.852296
#                                                random_radius_targets   227.853420
#                                                spots                  1333.260037
# gdf1_gdf1_overlay_intersection 2.0a1           random_center_targets   190.824178
#                                                random_radius_targets   291.330999
#                                                spots                  1451.532514
# gdf1_gdf1_overlay_union        2.0a1           random_center_targets   506.973575
#                                                random_radius_targets   641.480118
#                                                spots                  3563.415316
# gdf1_gdf2_overlay_difference   2.0a1           random_center_targets  1468.436132
#                                                random_radius_targets   472.935489
#                                                spots                  1175.293128
# gdf1_gdf2_overlay_intersection 2.0a1           random_center_targets   860.572231
#                                                random_radius_targets   366.438398
#                                                spots                  1065.455424
# gdf1_gdf2_overlay_union        2.0a1           random_center_targets  3820.776408
#                                                random_radius_targets  1468.157252
#                                                spots                  3054.334704
# gdf1_is_valid                  2.0a1           random_center_targets     7.566424
#                                                random_radius_targets    14.387575
#                                                spots                    46.402958
# gdf2_gdf1_overlay_difference   2.0a1           random_center_targets  1458.612882
#                                                random_radius_targets   580.658903
#                                                spots                  1280.127510
# gdf2_gdf2_overlay_difference   2.0a1           random_center_targets   179.650595
#                                                random_radius_targets   236.359346
#                                                spots                  1265.928183
# gdf2_gdf2_overlay_intersection 2.0a1           random_center_targets   187.280619
#                                                random_radius_targets   311.541159
#                                                spots                  1468.774243
# gdf2_gdf2_overlay_union        2.0a1           random_center_targets   498.352350
#                                                random_radius_targets   674.247628
#                                                spots                  3542.292063
# gdf2_is_valid                  2.0a1           random_center_targets     2.943344
#                                                random_radius_targets     5.608587
#                                                spots                    42.435309

# %%
timings.error.value_counts()
# Out:
# Series([], Name: error, dtype: int64)
